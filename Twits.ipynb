# %%
from textblob import TextBlob
import pandas as pd

# %%
df = pd.read_csv('../Resources/AMZNtwits.csv', encoding = "ISO-8859-1")
df.head()
# Out:
#       Date Stock                                               Twit
# 0  11/7/19  AMZN  2000 more $GRPN Long shares limit order at 2.9...
# 1  11/7/19  AMZN  FOOD FOR THOUGHT. When you see someone on thes...
# 2  11/7/19  AMZN  $AMZN we have all heard about the billions & b...
# 3  11/7/19  AMZN  $AAPL cnbc.com/2019/11/06/bill-ga... $GOOG  $M...
# 4  11/7/19  AMZN  $AMZN continuation from previous post: even Ja...

# %%
testimonial = TextBlob("2000 more $GRPN Long shares limit order at 2.91 today.  Groupon Plus/Select/Vouchers = priceless local O2O discoveries + overspending on discounts to upgrade experiences!  Preposterous market cap/PPS evaluations = $AMZN asks consumers to pay for expensive Prime yet EBAY/GRPN Goods deals are as good if not better w/o membership + Bitcoin blockchain garbage $OSTK + $SNAP super fugly GUI & majority under 25 demographic + overrated POS “social network” $PINS (obsolete GPS ads & majority female only demographic yet 19+!?!). #CluelessWallStreet #Amateurzon #Groupon4Life #GrouponPlus #GrouponSelect #LocalHeartGlobalImpact #VoucherOverspend #OwnTheExperience #TreatYourself2More #GrouponWorks #MakeLifeLessBoring #SpaceCatCuriosity  #Overschlock.com #CostNo #Limpinterest #SnapCrap #Couponsdotcomblows #GrubFlub #Pricelame #ChewFlea #Walfart #Rofluku #YelpSucks #PinduoDOH #KeepCalmAndGroupon #Yay4Ebay #Twitterrific #AngiesListless")
testimonial.sentiment
# Out:
# Sentiment(polarity=0.1606060606060606, subjectivity=0.509090909090909)

# %%
testimonial = TextBlob("Textblob is terribly easy to use. Will never stop using.")
testimonial.sentiment
# Out:
# Sentiment(polarity=0.43333333333333335, subjectivity=0.8333333333333334)

# %%
df = df.astype('str', copy=False)

# %%
df[['polarity', 'subjectivity']] = df['Twit'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
df.head(100)
# Out:
#        Date Stock                                               Twit  \
# 0   11/7/19  AMZN  2000 more $GRPN Long shares limit order at 2.9...
# 1   11/7/19  AMZN  FOOD FOR THOUGHT. When you see someone on thes...
# 2   11/7/19  AMZN  $AMZN we have all heard about the billions & b...
# 3   11/7/19  AMZN  $AAPL cnbc.com/2019/11/06/bill-ga... $GOOG  $M...
# 4   11/7/19  AMZN  $AMZN continuation from previous post: even Ja...
# 5   11/7/19  AMZN  $AMZN $COST $M $KSS $WMT Will Consumer Confide...
# 6   11/7/19  AMZN  $DIS $AMZN Disney Trades Higher On Q4 Earnings...
# 7   11/7/19  AMZN  $AMZN Exclusive: Sears says it has secured a $...
# 8   11/7/19  AMZN  $AMZN $TGT $BBY $WMT $KSS Facing shorter holid...
# 9   11/7/19  AMZN  $AMZN Amazon To Build Second Robotics Developm...
# 10  11/7/19  AMZN  $DIS $NFLX $AMZN $AAPL $T 'Lion King' lifts Di...
# 11  11/7/19  AMZN  $AMZN UPDATE 1-Amazon Australia signs up Zip C...
# 12  11/7/19  AMZN  $ROKU $NFLX $AAPL $DIS $AMZN UPDATE 2-Roku qua...
# ...

# %%
Group_df = df.groupby(['Date'])['polarity'].mean()
Group_df
# Out:
# Date
# 11/10/19    0.074791
# 11/11/19    0.042040
# 11/12/19    0.065407
# 11/13/19    0.073582
# 11/14/19    0.066152
# 11/15/19    0.029659
# 11/16/19    0.066878
# 11/17/19    0.095692
# 11/7/19     0.052850
# 11/8/19     0.056396
# 11/9/19     0.034317
# nan         0.000000
# Name: polarity, dtype: float64
