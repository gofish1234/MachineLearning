# %%
# Dependencies
import requests
import json

# %%
# URL of page to be scraped
url = 'https://api.stocktwits.com/api/2/streams/symbol/AMRS.json'

# %%
 # Retrieve page with the requests module
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"response":{"status":200},"symbol":{"id":9305,"symbol":"AMRS","title":"Amyris Inc","aliases":[],"is_following":false,"watchlist_count":18943},"cursor":{"more":true,"since":183819098,"max":183701553},"messages":[{"id":183819098,"body":"$AMRS\\n\\nLooks like our little baby is forgetting the crawl and walk part and has decided simply to run...","created_at":"2019-11-15T00:53:43Z","user":{"id":1028705,"username":"GreenAndGreen","name":"GreenAndGreen","avatar_url":"https://avatars.stocktwits.com/production/1028705/thumb-1570078495.png","avatar_url_ssl":"https://avatars.stocktwits.com/production/1028705/thumb-1570078495.png","join_date":"2017-04-13","official":false,"identity":"User","classification":[],"followers":39,"following":3,"ideas":1483,"watchlist_stocks_count":14,"like_count":843,"plus_tier":"","premium_room":""},"source":{"id":2269,"title":"StockTwits Web","url":"https://stocktwits.com"},"symbols":[{"id":9305,"symbol":"AMRS","title":"Amyris Inc","aliases":[],"is_following":fal
# ...

# %%
response.json()
# Out:
# {'response': {'status': 200},
#  'symbol': {'id': 9305,
#   'symbol': 'AMRS',
#   'title': 'Amyris Inc',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 18943},
#  'cursor': {'more': True, 'since': 183819098, 'max': 183701553},
#  'messages': [{'id': 183819098,
#    'body': '$AMRS\n\nLooks like our little baby is forgetting the crawl and walk part and has decided simply to run...',
#    'created_at': '2019-11-15T00:53:43Z',
#    'user': {'id': 1028705,
#     'username': 'GreenAndGreen',
#     'name': 'GreenAndGreen',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1028705/thumb-1570078495.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1028705/thumb-1570078495.png',
#     'join_date': '2017-04-13',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 39,
#     'following': 3,
#     'ideas': 1483,
#     'watchlist_stocks_count': 14,
#     'like_count': 843,
#     'plus_tier': '',
# ...

# %%
response.json()['response']
# Out:
# {'status': 200}

# %%
Messages = response.json()['messages']

# %%
 # Examine the results, then determine element that contains sought info
response.json()
# Out:
# {'response': {'status': 200},
#  'symbol': {'id': 9305,
#   'symbol': 'AMRS',
#   'title': 'Amyris Inc',
#   'aliases': [],
#   'is_following': False,
#   'watchlist_count': 18943},
#  'cursor': {'more': True, 'since': 183819098, 'max': 183701553},
#  'messages': [{'id': 183819098,
#    'body': '$AMRS\n\nLooks like our little baby is forgetting the crawl and walk part and has decided simply to run...',
#    'created_at': '2019-11-15T00:53:43Z',
#    'user': {'id': 1028705,
#     'username': 'GreenAndGreen',
#     'name': 'GreenAndGreen',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1028705/thumb-1570078495.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1028705/thumb-1570078495.png',
#     'join_date': '2017-04-13',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 39,
#     'following': 3,
#     'ideas': 1483,
#     'watchlist_stocks_count': 14,
#     'like_count': 843,
#     'plus_tier': '',
# ...

# %%
#Loop through returned results
for item in Messages.body
    #Twit = Messages['body'][0]
    
print(body)
# Out:
#   File "<ipython-input-54-bfe460670e24>", line 2
#     for item in Messages.body
#                              ^
# SyntaxError: invalid syntax

# %%
#future code ----
    api_results = {}
    for items in domains_to_check:
        url = 'https://openpagerank.com/api/v1.0/getPageRank?domains%5B0%5D=' + items
        request = requests.get(url, headers=headers)
        api_result = request.json()
