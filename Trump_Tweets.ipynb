# %%
import tweepy

# %%
consumer_key = "uQ5TkHoiRF6NoWFBmazr8NPab"
consumer_secret = "qwecDaD1d9tQqN3J8PfJfTRt0sXN8sBZHRAHtqnuIRsuJwXq6I"
access_token = "1195739404972822528-yLyrhti3vnEEjoR2ljmR3Cb7UUdoY2"
access_token_secret = "f5cALlXOh9G0glz66HODgZNl5R1yxLPsJZXg9e8g3xiTt"

# %%
# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth)

# %%
# The Twitter user who we want to get tweets from
name = "realDonaldTrump"
# Number of tweets to pull
tweetCount = 500

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
   print (tweet.text)
# Out:
# https://t.co/Mqj5tXaDAz
# “All they do is bring up witnesses who didn’t witness anything.” @KatrinaPierson @SteveHiltonx  Nothing matters exc… https://t.co/mOVG17IFDL
# “The Impeachment started before he even became President.” @greggutfeld  @FoxNews
# https://t.co/1Rg66Tn4uP
# https://t.co/D66PEkuX6d
# Where is the Fake Whistleblower?
# https://t.co/ru2n7i2gzu
# Republicans &amp; others must remember, the Ukrainian President and Foreign Minister both said that there was no pressu… https://t.co/mFL4wwDR8b
# The Crazed, Do Nothing Democrats are turning Impeachment into a routine partisan weapon. That is very bad for our C… https://t.co/8imWgyrBin
# Tell Jennifer Williams, whoever that is, to read BOTH transcripts of the presidential calls, &amp; see the just release… https://t.co/z5Iwr6LSOp
# https://t.co/I3lO117SVh
# Paul Krugman of @nytimes has been wrong about me from the very beginning. Anyone who has followed his “words of wis… https://t.co/vLB1qdYWz6
# ...

# %%
len(results)
# Out:
# 200

# %%
import pandas as pd

# %%
list_tweets = list(results)
[print(tweet.text, end='\n\n') for tweet in list_tweets[0:5]];
# Out:
# https://t.co/Mqj5tXaDAz
#
# “All they do is bring up witnesses who didn’t witness anything.” @KatrinaPierson @SteveHiltonx  Nothing matters exc… https://t.co/mOVG17IFDL
#
# “The Impeachment started before he even became President.” @greggutfeld  @FoxNews
#
# https://t.co/1Rg66Tn4uP
#
# https://t.co/D66PEkuX6d

# %%
tweet_text = []
tweet_date = []

for tweet in list_tweets:
    tweet_text.append(tweet.text)
    tweet_date.append(tweet.created_at)

# %%
df = pd.DataFrame({'tweet':tweet_text, 'date':tweet_date})

# %%
df.head()
# Out:
#                                                tweet                date
# 0                            https://t.co/Mqj5tXaDAz 2019-11-18 04:38:28
# 1  “All they do is bring up witnesses who didn’t ... 2019-11-18 03:39:38
# 2  “The Impeachment started before he even became... 2019-11-18 02:40:04
# 3                            https://t.co/1Rg66Tn4uP 2019-11-17 22:57:43
# 4                            https://t.co/D66PEkuX6d 2019-11-17 22:51:37

# %%
# Export file as a CSV, without the Pandas index, but with the header
df.to_csv("trump_tweets.csv", index=False, header=True)
