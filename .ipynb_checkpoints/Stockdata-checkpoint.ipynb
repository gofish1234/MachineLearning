# %%
import quandl
import pandas as pd
import json
import numpy as np
import requests
import matplotlib.pyplot as plt
import dateutil.parser

# %%
quandl.ApiConfig.api_key = "1sNXfWjF5c7B4CLEZZyT"

# %%
start = pd.to_datetime('2018-02-01')
end = pd.to_datetime('2019-11-01')
data = quandl.get_table('WIKI/PRICES', 
                        ticker = ['WMT','TGT','AMZN','M','BBY','COST','HD'], 
                        date = { 'gte': start, 'lte': end })

# %%
data.head(100)
# Out:
#      ticker       date    open      high       low   close      volume  \
# None
# 0       WMT 2018-03-27   87.96   88.0400   85.4800   86.05   6395554.0
# 1       WMT 2018-03-26   86.22   87.6900   86.1100   87.50   8640866.0
# 2       WMT 2018-03-23   87.35   87.7400   85.2800   85.42   9762296.0
# 3       WMT 2018-03-22   87.53   88.2700   86.9900   87.14  11338049.0
# 4       WMT 2018-03-21   87.89   89.6800   87.6800   88.18  11687930.0
# 5       WMT 2018-03-20   87.86   88.1470   87.3700   87.95   8040214.0
# 6       WMT 2018-03-19   88.91   89.0750   87.1000   87.45  10774186.0
# 7       WMT 2018-03-16   87.72   90.0900   87.5000   89.17  28057241.0
# 8       WMT 2018-03-15   87.68   88.7900   85.9030   87.51  16136617.0
# 9       WMT 2018-03-14   88.51   88.9900   87.5000   87.67  11021885.0
# 10      WMT 2018-03-13   88.39   88.9000   87.9801   88.30   7092501.0
# 11      WMT 2018-03-12   88.70   89.4400   87.8800   88.07   8212498.0
# ...

# %%
len(data)
# Out:
# 266
