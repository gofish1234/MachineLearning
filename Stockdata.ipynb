# %%
import pandas as pd
import quandl
import matplotlib.pyplot as plt

# %%
quandl.ApiConfig.api_key = "1sNXfWjF5c7B4CLEZZyT"

# %%
start = pd.to_datetime('2018-02-01')
end = pd.to_datetime('2019-02-01')
data = quandl.get_table('WIKI/PRICES', 
                        ticker = ['TGT'], 
                        date = { 'gte': start, 'lte': end })

# Alternatively, you can just type in the date:
#data = quandl.get_table('WIKI/PRICES', 
#                       ticker = ['JNJ'], 
#                       date = { 'gte': '2016-02-01', 'lte': '2018-02-01' })

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head(10)
# Out:
#      ticker       date   open   high    low  close     volume  ex-dividend  \
# None
# 0       TGT 2018-03-27  70.79  70.90  68.23  68.51  5828381.0          0.0
# 1       TGT 2018-03-26  68.67  70.63  68.65  70.28  4875792.0          0.0
# 2       TGT 2018-03-23  69.72  70.21  67.77  67.88  5137447.0          0.0
# 3       TGT 2018-03-22  69.85  70.48  68.81  68.89  5292867.0          0.0
# 4       TGT 2018-03-21  71.18  71.50  70.14  70.14  3782333.0          0.0
# 5       TGT 2018-03-20  70.60  71.77  70.51  71.56  4930709.0          0.0
# 6       TGT 2018-03-19  70.92  71.32  70.11  70.34  3163004.0          0.0
# 7       TGT 2018-03-16  70.55  71.43  70.41  70.99  7194014.0          0.0
# 8       TGT 2018-03-15  71.28  71.50  70.28  70.63  5635445.0          0.0
# 9       TGT 2018-03-14  71.44  71.72  70.38  70.65  4660258.0          0.0
#
#       split_ratio  adj_open  adj_high  adj_low  adj_close  adj_volume
# None
# ...

# %%
data.tail(1)
# Out:
#      ticker       date   open   high    low  close     volume  ex-dividend  \
# None
# 37      TGT 2018-02-01  74.63  75.65  74.15  74.97  4647564.0          0.0
#
#       split_ratio  adj_open  adj_high  adj_low  adj_close  adj_volume
# None
# 37            1.0     74.63     75.65    74.15      74.97   4647564.0

# %%
# %matplotlib inline
fig = plt.figure()
axes = fig.add_axes([0,0,2,1])
axes.plot(data['date'],data['adj_close'])
axes.set_xlabel('Date')
axes.set_ylabel('Adjusted Closing Price')
axes.set_title('JNJ - Adjusted Closing Price')
# Out:
# Text(0.5, 1.0, 'JNJ - Adjusted Closing Price')
